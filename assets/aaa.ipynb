# %% [markdown]
# # Test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# data
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D']).cumsum()

# plot
plt.figure()
df.plot()
plt.legend(loc='best')

# %cpaste
# Out:
# UsageError: Line magic function `%cpaste` not found.

# %%
# %alias
# Out:
# Total number of aliases: 12
# [('cat', 'cat'),
#  ('cp', 'cp'),
#  ('ldir', 'ls -F -o --color %l | grep /$'),
#  ('lf', 'ls -F -o --color %l | grep ^-'),
#  ('lk', 'ls -F -o --color %l | grep ^l'),
#  ('ll', 'ls -F -o --color'),
#  ('ls', 'ls -F --color'),
#  ('lx', 'ls -F -o --color %l | grep ^-..x'),
#  ('mkdir', 'mkdir'),
#  ('mv', 'mv'),
#  ('rm', 'rm'),
#  ('rmdir', 'rmdir')]

# %%
# %env
# Out:
# {'HOSTNAME': 'jupyter-1-1wpzz',
#  'KUBERNETES_PORT': 'tcp://172.30.0.1:443',
#  'KUBERNETES_PORT_443_TCP_PORT': '443',
#  'SHELL': '/bin/bash',
#  'NB_USER': 'jovyan',
#  'NSS_WRAPPER_GROUP': '/etc/group',
#  'OPENSHIFT_BUILD_NAME': 'jupyter-1',
#  'KUBERNETES_SERVICE_PORT': '443',
#  'LD_PRELOAD': '/usr/local/nss_wrapper/lib64/libnss_wrapper.so',
#  'KUBERNETES_PORT_53_TCP': 'tcp://172.30.0.1:53',
#  'KUBERNETES_SERVICE_HOST': '172.30.0.1',
#  'OPENSHIFT_BUILD_SOURCE': 'http://gogs-cicd.statwb.eu.novartis.net/dbrrt/sample-notebook',
#  'LC_ALL': 'en_US.UTF-8',
#  'NO_PROXY': '.cluster.local,PHCHBS-SD220159.eu.novartis.net,PHCHBS-SD220160.eu.novartis.net,eu.novartis.net,localhost,novartis.net,phchbs-sd220158.eu.novartis.net',
#  'KUBERNETES_PORT_53_UDP': 'udp://172.30.0.1:53',
#  'KUBERNETES_PORT_53_TCP_PORT': '53',
#  'http_proxy': 'http://proxy.eu.novartis.net:2011',
#  'KUBERNETES_SERVICE_PORT_DNS': '53',
#  'JUPYTER_PORT_8888_TCP_PORT': '8888',
# ...
